# %%
import matplotlib.pyplot as plt
import os

# Sử dụng đường dẫn tuyệt đối đến thư mục gốc
BASE_DIR = "/home/aorus/workspaces/magiv2"
num_speaking = len(os.listdir(os.path.join(BASE_DIR, "module", "tail_classification", "cropped_bubbles", "speaking")))
num_thinking = len(os.listdir(os.path.join(BASE_DIR, "module", "tail_classification", "cropped_bubbles", "thinking")))

print(f"Number of speaking bubbles: {num_speaking}")
print(f"Number of thinking bubbles: {num_thinking}")
# Out:
# Number of speaking bubbles: 460
# Number of thinking bubbles: 151
