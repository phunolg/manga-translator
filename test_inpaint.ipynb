# %%
import glob
import io
import os
from pprint import pprint
import zipfile
from PIL import Image
import requests, json, mimetypes
import matplotlib.pyplot as plt
from settings import BASE_DIR
# %matplotlib inline
URL = "http://localhost:8008/main/inpaint"
def visualize_result(translated_image, original_image_path, manga_name, is_show_result = False):
    original_image = Image.open(original_image_path)
    print(
        f"Kích thước ảnh gốc: {original_image.size}, Kích thước ảnh AI dịch: {translated_image.size}")
    # Lấy tên tập và tên file
    filename = os.path.basename(original_image_path)
    chapter = os.path.basename(os.path.dirname(original_image_path))

    # Tạo thư mục và lưu ảnh AI dịch
    ai_translated_dir = os.path.join("test_commic", "output", manga_name, "gpt_translated", chapter)
    os.makedirs(ai_translated_dir, exist_ok=True)

    ai_save_path = os.path.join(ai_translated_dir, filename)
    # Chuyển đổi từ RGBA sang RGB nếu cần
    if translated_image.mode == 'RGBA':
        translated_image = translated_image.convert('RGB')
    translated_image.save(ai_save_path)

    # Hiển thị ảnh gốc và ảnh dịch song song
    fig = plt.figure(figsize=(14, 24))  # Tăng kích thước hiển thị

    ax1 = plt.subplot(1, 3, 1)
    ax1.set_title("Ảnh gốc")
    ax1.imshow(original_image)
    ax1.axis('off')


    team_translated_path = os.path.join("test_commic", "data" , manga_name, "team_translated", chapter, filename)
    print(f"Đường dẫn ảnh dịch tay: {team_translated_path}")
    has_team_translation = os.path.exists(team_translated_path)

    if has_team_translation:
        manual_translated = Image.open(team_translated_path)
        ax2 = plt.subplot(1, 3, 2)
        ax2.set_title("Ảnh dịch tay")
        ax2.imshow(manual_translated)
        ax2.axis('off')

        ax3 = plt.subplot(1, 3, 3)
        ax3.set_title(f"AI dịch")
        ax3.imshow(translated_image)
        ax3.axis('off')
    else:
        ax2 = plt.subplot(1, 3, 2)
        ax2.set_title(f"AI dịch")
        ax2.imshow(translated_image)
        ax2.axis('off')

    # ---- Save fig ----
    compare_dir = os.path.join("test_commic", "output", manga_name, "compare", chapter)
    os.makedirs(compare_dir, exist_ok=True)
    compare_path = os.path.join(compare_dir, filename)
    plt.savefig(compare_path, dpi=200, bbox_inches='tight')
    
    # Hiển thị hình ảnh trong notebook
    if is_show_result:
        plt.show()
    
    plt.close(fig)


def run_inpaint(manga_name, chapter_number, original_image_paths, batch_size = 5, show_result = False):
    print(manga_name, chapter_number, original_image_paths)
    page_numbers = [int(path.split("/")[-1].split(".")[0]) for path in original_image_paths]
    # Sử dụng ExitStack để quản lý file handles
    from contextlib import ExitStack

    total_pages = len(original_image_paths)
    total_batches = (total_pages + batch_size - 1) // batch_size
    print(f"Tổng số trang: {total_pages}, chia thành {total_batches} batch")

    all_results = []
    
    for i in range(0, total_pages, batch_size):
        batch_paths = original_image_paths[i:i+batch_size]
        batch_numbers = page_numbers[i:i+batch_size]
        current_batch = i // batch_size + 1
        
        print(f"\nĐang xử lý batch {current_batch}/{total_batches} ({len(batch_paths)} trang)")
        
        # Tạo form data cho batch này
        batch_form_data = [
            ("target_lang", "vietnamese"),
            ("story_name", str(manga_name)),
            ("chapter_number", str(chapter_number)),
        ]
        print(batch_form_data)
        
        for n in batch_numbers:
            batch_form_data.append(("page_numbers", str(n)))
        
        # Sử dụng ExitStack để quản lý file handles
        with ExitStack() as stack:
            batch_files = [
                ("page_images", 
                (path.split("/")[-1], 
                stack.enter_context(open(path, "rb")), "image/jpeg")
                )
                for path in batch_paths
            ]
            
            # Thiết lập timeout dài hơn (5 phút)
            timeout = 3000
            
            # Gửi request cho batch hiện tại
            response = requests.post(URL, data=batch_form_data, files=batch_files, timeout=timeout)
            
            if response.status_code == 200:
                # Xử lý file ZIP
                with zipfile.ZipFile(io.BytesIO(response.content)) as zip_file:
                    # Lấy danh sách các file trong ZIP
                    file_names = zip_file.namelist()
                    print(file_names)
                    print(f"Nhận được {len(file_names)} file từ batch {current_batch}")
                    
                    for file_name, original_image_path in zip(file_names, batch_paths):
                        # Đọc từng file trong ZIP
                        with zip_file.open(file_name) as file:
                            # Chuyển đổi thành đối tượng Image
                            translated_image = Image.open(file)
                            # Gọi hàm visualize cho từng ảnh
                            visualize_result(translated_image, original_image_path, manga_name, is_show_result=show_result)
            else:
                print(f"Lỗi batch {current_batch}: {response.status_code}")
                print(response.text)

# %%
THIS IS OUR TREASURED
DISH, THE RED WATER
MAP HOTPOT
ĐÂY LÀ MÓN TRÂN PHẨM
CỦA QUÁN, HỒNG THỦY NGƯ ĐỒLẨU

# %%
CHAPTER_NUMBER = 134
PAGE_NUMBER = 8
MANGA_NAME = "Yule"
folder_path = f"{BASE_DIR}/test_commic/data/{MANGA_NAME}"
chapter_folder_path = os.path.join(folder_path, "Raw", str(CHAPTER_NUMBER))
original_image_paths = [f"{BASE_DIR}/test_commic/data/Yule/Raw/{CHAPTER_NUMBER}/{PAGE_NUMBER}.jpg"]
run_inpaint(MANGA_NAME, CHAPTER_NUMBER, original_image_paths, batch_size=11, show_result=True)
# Out:
# Yule 134 ['/home/aorus/workspaces/magiv2/test_commic/data/Yule/Raw/134/8.jpg']
# Tổng số trang: 1, chia thành 1 batch
#
# Đang xử lý batch 1/1 (1 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '134')]
# ['8.png']
# Nhận được 1 file từ batch 1
# Kích thước ảnh gốc: (1000, 2380), Kích thước ảnh AI dịch: (1000, 2380)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/8.jpg

# %%
from utils.utils import bbox_to_quad

bbox_to_quad(test_bboxes[0])
# Out:
# array([[[   0.        ,   80.50917053],
#         [ 761.48962402,   80.50917053],
#         [ 761.48962402,  299.39590454],
#         [   0.        ,  299.39590454]],
#
#        [[ 187.38969421, 2081.58398438],
#         [ 999.        , 2081.58398438],
#         [ 999.        , 2182.42236328],
#         [ 187.38969421, 2182.42236328]],
#
#        [[   0.        , 2870.49072266],
#         [ 750.60205078, 2870.49072266],
#         [ 750.60205078, 3230.95507812],
#         [   0.        , 3230.95507812]],
#
#        [[   0.        , 4316.24609375],
#         [ 562.27661133, 4316.24609375],
#         [ 562.27661133, 4558.85449219],
#         [   0.        , 4558.85449219]]])

# %%
import cv2

test_bboxes = [[[0.0, 80.50917053222656, 761.4896240234375, 299.3959045410156],
  [187.3896942138672, 2081.583984375, 999.0, 2182.42236328125],
  [0.0, 2870.49072265625, 750.60205078125, 3230.955078125],
  [0.0, 4316.24609375, 562.276611328125, 4558.8544921875]]]

img_path = "/home/aorus/workspaces/magiv2/test_commic/output/Yule/gpt_translated/133/7.jpg"
image = cv2.imread(img_path)

# Convert BGR (OpenCV) to RGB (matplotlib)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Draw bounding boxes
for box in test_bboxes[0]:
    x1, y1, x2, y2 = map(int, box)
    cv2.rectangle(image, (x1, y1), (x2, y2), color=(255, 0, 0), thickness=4)

# Show image
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Debug Text Render ENG

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 3
#       1 import numpy as np
#       2 from typing import List, Tuple
# ----> 3 from module.rendering.text_render import get_char_glyph
#       5 inputs = {
#       6     "font_color": [
#       7         0,
#    (...)
#      25     "lang": "vi"
#      26 }
#      28 font_color=(0, 0, 0)               # Màu chữ (mặc định: đen)
#
# File ~/workspaces/magiv2/module/rendering/__init__.py:16
#      13 from utils.color import fg_bg_compare
#      15 # from .ballon_extractor import extract_ballon_region
# ---> 16 from . import text_render
#      17 from .text_render_eng import TextRenderEng
#      18 from .text_render_pillow_eng import render_textblock_list_eng as render_textblock_list_eng_pillow
#
# File ~/workspaces/magiv2/module/rendering/text_render.py:10
#       8 from pathlib import Path
#       9 from typing import Tuple, Optional, List
# ---> 10 from hyphen.textwrap2 import TextWrapper
#      11 from hyphen.dictools import list_installed as HYPHENATOR_LANGUAGES
#      12 from langcodes import standardize_tag
#
# ModuleNotFoundError: No module named 'hyphen.textwrap2'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 params = load_function_inputs_pickle()
#       2 print(params)
#
# Cell In[10], line 5, in load_function_inputs_pickle(file_path)
#       3 def load_function_inputs_pickle(file_path=os.path.join(BASE_DIR, "debug","render_textblock_list_eng_inputs.pkl")):
#       4     with open(file_path, "rb") as f:
# ----> 5         data = pickle.load(f)
#       6     self_obj = data["self_obj"]
#       7     params = data["params"]
#
# File ~/workspaces/magiv2/module/utils/__init__.py:2
# ----> 2 from .log import *
#       3 from .generic import *
#       4 from .textblock import *
#
# File ~/workspaces/magiv2/module/utils/log.py:4
#       1 import logging
#       2 import colorama
# ----> 4 from .generic import replace_prefix
#       6 ROOT_TAG = 'manga-translator'
#       8 class Formatter(logging.Formatter):
#
# File ~/workspaces/magiv2/module/utils/generic.py:338
#     335     return dst_points
#     337 from shapely.geometry import Polygon
# --> 338 from module.utils.textblock import TextBlock
#     342 class BBox(object):
#     343     def __init__(self, x: int, y: int, w: int, h: int, text: str, prob: float, fg_r: int = 0, fg_g: int = 0, fg_b: int = 0, bg_r: int = 0, bg_g: int = 0, bg_b: int = 0):
#
# File ~/workspaces/magiv2/module/utils/textblock.py:8
#       6 import copy
#       7 import re
# ----> 8 import py3langid as langid
#       9 # from ..detection.ctd_utils.utils.imgproc_utils import union_area, xywh2xyxypoly
#      10
#      11 # LANG_LIST = ['eng', 'ja', 'unknown']
#      12 # LANGCLS2IDX = {'eng': 0, 'ja': 1, 'unknown': 2}
#      14 from module.utils.panel.kumikolib import Kumiko
#
# ModuleNotFoundError: No module named 'py3langid'

# %%
chapter_number = 134
manga_name = "Yule"
folder_path = f"/home/aorus/workspaces/test_commic/data/{manga_name}"
chapter_folder_path = os.path.join(folder_path, "Raw", str(chapter_number))
original_image_paths = glob.glob(os.path.join(chapter_folder_path, "*.jpg"))
run_inpaint(manga_name, chapter_number, original_image_paths, batch_size=10)
# Out:
# Yule 134 ['/home/aorus/workspaces/test_commic/data/Yule/Raw/134/17.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/11.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/23.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/7.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/22.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/18.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/3.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/19.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/9.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/12.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/13.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/5.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/20.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/14.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/1.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/2.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/8.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/4.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/15.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/16.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/10.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/6.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/21.jpg']
# Tổng số trang: 23, chia thành 3 batch
#
# Đang xử lý batch 1/3 (10 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '134')]
# ['17.png', '11.png', '23.png', '7.png', '22.png', '18.png', '3.png', '19.png', '9.png', '12.png']
# Nhận được 10 file từ batch 1
# Kích thước ảnh gốc: (1000, 3345), Kích thước ảnh AI dịch: (1000, 3345)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/17.jpg
# Kích thước ảnh gốc: (1000, 3990), Kích thước ảnh AI dịch: (1000, 3990)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/11.jpg
# Kích thước ảnh gốc: (1000, 4845), Kích thước ảnh AI dịch: (1000, 4845)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/23.jpg
# Kích thước ảnh gốc: (1000, 2665), Kích thước ảnh AI dịch: (1000, 2665)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/7.jpg
# Kích thước ảnh gốc: (1000, 3065), Kích thước ảnh AI dịch: (1000, 3065)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/22.jpg
# Kích thước ảnh gốc: (1000, 4160), Kích thước ảnh AI dịch: (1000, 4160)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/18.jpg
# Kích thước ảnh gốc: (1000, 4190), Kích thước ảnh AI dịch: (1000, 4190)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/3.jpg
# Kích thước ảnh gốc: (1000, 4025), Kích thước ảnh AI dịch: (1000, 4025)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/19.jpg
# Kích thước ảnh gốc: (1000, 4120), Kích thước ảnh AI dịch: (1000, 4120)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/9.jpg
# Kích thước ảnh gốc: (1000, 3325), Kích thước ảnh AI dịch: (1000, 3325)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/12.jpg
#
# Đang xử lý batch 2/3 (10 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '134')]
# ['13.png', '5.png', '20.png', '14.png', '1.png', '2.png', '8.png', '4.png', '15.png', '16.png']
# Nhận được 10 file từ batch 2
# Kích thước ảnh gốc: (1000, 4190), Kích thước ảnh AI dịch: (1000, 4190)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/13.jpg
# Kích thước ảnh gốc: (1000, 4025), Kích thước ảnh AI dịch: (1000, 4025)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/5.jpg
# Kích thước ảnh gốc: (1000, 5000), Kích thước ảnh AI dịch: (1000, 5000)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/20.jpg
# Kích thước ảnh gốc: (1000, 3425), Kích thước ảnh AI dịch: (1000, 3425)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/14.jpg
# Kích thước ảnh gốc: (1000, 4520), Kích thước ảnh AI dịch: (1000, 4520)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/1.jpg
# Kích thước ảnh gốc: (1000, 5000), Kích thước ảnh AI dịch: (1000, 5000)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/2.jpg
# Kích thước ảnh gốc: (1000, 2380), Kích thước ảnh AI dịch: (1000, 2380)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/8.jpg
# Kích thước ảnh gốc: (1000, 4635), Kích thước ảnh AI dịch: (1000, 4635)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/4.jpg
# Kích thước ảnh gốc: (1000, 4210), Kích thước ảnh AI dịch: (1000, 4210)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/15.jpg
# Kích thước ảnh gốc: (1000, 3025), Kích thước ảnh AI dịch: (1000, 3025)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/16.jpg
#
# Đang xử lý batch 3/3 (3 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '134')]
# ['10.png', '6.png', '21.png']
# Nhận được 3 file từ batch 3
# Kích thước ảnh gốc: (1000, 4170), Kích thước ảnh AI dịch: (1000, 4170)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/10.jpg
# Kích thước ảnh gốc: (1000, 3050), Kích thước ảnh AI dịch: (1000, 3050)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/6.jpg
# Kích thước ảnh gốc: (1000, 5000), Kích thước ảnh AI dịch: (1000, 5000)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/21.jpg

# %%
chapter_numbers = [134, 135, 136, 137]
for chapter_number in chapter_numbers:
    manga_name = "Yule"
    folder_path = f"/home/aorus/workspaces/test_commic/data/{manga_name}"
    chapter_folder_path = os.path.join(folder_path, "Raw", str(chapter_number))
    original_image_paths = glob.glob(os.path.join(chapter_folder_path, "*.jpg"))
    run_inpaint(manga_name, chapter_number, original_image_paths, batch_size=10)
# Out:
# Yule 134 ['/home/aorus/workspaces/test_commic/data/Yule/Raw/134/17.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/11.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/23.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/7.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/22.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/18.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/3.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/19.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/9.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/12.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/13.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/5.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/20.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/14.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/1.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/2.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/8.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/4.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/15.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/16.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/10.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/6.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/134/21.jpg']
# Tổng số trang: 23, chia thành 3 batch
#
# Đang xử lý batch 1/3 (10 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '134')]
# ['17.png', '11.png', '23.png', '7.png', '22.png', '18.png', '3.png', '19.png', '9.png', '12.png']
# Nhận được 10 file từ batch 1
# Kích thước ảnh gốc: (1000, 3345), Kích thước ảnh AI dịch: (1000, 3345)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/17.jpg
# Kích thước ảnh gốc: (1000, 3990), Kích thước ảnh AI dịch: (1000, 3990)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/11.jpg
# Kích thước ảnh gốc: (1000, 4845), Kích thước ảnh AI dịch: (1000, 4845)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/23.jpg
# Kích thước ảnh gốc: (1000, 2665), Kích thước ảnh AI dịch: (1000, 2665)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/7.jpg
# Kích thước ảnh gốc: (1000, 3065), Kích thước ảnh AI dịch: (1000, 3065)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/22.jpg
# Kích thước ảnh gốc: (1000, 4160), Kích thước ảnh AI dịch: (1000, 4160)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/18.jpg
# Kích thước ảnh gốc: (1000, 4190), Kích thước ảnh AI dịch: (1000, 4190)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/3.jpg
# Kích thước ảnh gốc: (1000, 4025), Kích thước ảnh AI dịch: (1000, 4025)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/19.jpg
# Kích thước ảnh gốc: (1000, 4120), Kích thước ảnh AI dịch: (1000, 4120)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/9.jpg
# Kích thước ảnh gốc: (1000, 3325), Kích thước ảnh AI dịch: (1000, 3325)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/12.jpg
#
# Đang xử lý batch 2/3 (10 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '134')]
# ['13.png', '5.png', '20.png', '14.png', '1.png', '2.png', '8.png', '4.png', '15.png', '16.png']
# Nhận được 10 file từ batch 2
# Kích thước ảnh gốc: (1000, 4190), Kích thước ảnh AI dịch: (1000, 4190)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/13.jpg
# Kích thước ảnh gốc: (1000, 4025), Kích thước ảnh AI dịch: (1000, 4025)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/5.jpg
# Kích thước ảnh gốc: (1000, 5000), Kích thước ảnh AI dịch: (1000, 5000)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/20.jpg
# Kích thước ảnh gốc: (1000, 3425), Kích thước ảnh AI dịch: (1000, 3425)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/14.jpg
# Kích thước ảnh gốc: (1000, 4520), Kích thước ảnh AI dịch: (1000, 4520)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/1.jpg
# Kích thước ảnh gốc: (1000, 5000), Kích thước ảnh AI dịch: (1000, 5000)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/2.jpg
# Kích thước ảnh gốc: (1000, 2380), Kích thước ảnh AI dịch: (1000, 2380)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/8.jpg
# Kích thước ảnh gốc: (1000, 4635), Kích thước ảnh AI dịch: (1000, 4635)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/4.jpg
# Kích thước ảnh gốc: (1000, 4210), Kích thước ảnh AI dịch: (1000, 4210)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/15.jpg
# Kích thước ảnh gốc: (1000, 3025), Kích thước ảnh AI dịch: (1000, 3025)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/16.jpg
#
# Đang xử lý batch 3/3 (3 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '134')]
# ['10.png', '6.png', '21.png']
# Nhận được 3 file từ batch 3
# Kích thước ảnh gốc: (1000, 4170), Kích thước ảnh AI dịch: (1000, 4170)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/10.jpg
# Kích thước ảnh gốc: (1000, 3050), Kích thước ảnh AI dịch: (1000, 3050)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/6.jpg
# Kích thước ảnh gốc: (1000, 5000), Kích thước ảnh AI dịch: (1000, 5000)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/134/21.jpg
# Yule 135 ['/home/aorus/workspaces/test_commic/data/Yule/Raw/135/17.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/11.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/23.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/7.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/22.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/18.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/25.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/3.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/19.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/9.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/12.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/13.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/5.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/20.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/14.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/24.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/1.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/2.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/8.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/4.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/15.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/16.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/10.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/6.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/135/21.jpg']
# Tổng số trang: 25, chia thành 3 batch
#
# Đang xử lý batch 1/3 (10 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '135')]
# ['17.png', '11.png', '23.png', '7.png', '22.png', '18.png', '25.png', '3.png', '19.png', '9.png']
# Nhận được 10 file từ batch 1
# Kích thước ảnh gốc: (1000, 4525), Kích thước ảnh AI dịch: (1000, 4525)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/17.jpg
# Kích thước ảnh gốc: (1000, 3770), Kích thước ảnh AI dịch: (1000, 3770)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/11.jpg
# Kích thước ảnh gốc: (1000, 4105), Kích thước ảnh AI dịch: (1000, 4105)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/23.jpg
# Kích thước ảnh gốc: (1000, 4465), Kích thước ảnh AI dịch: (1000, 4465)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/7.jpg
# Kích thước ảnh gốc: (1000, 5675), Kích thước ảnh AI dịch: (1000, 5675)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/22.jpg
# Kích thước ảnh gốc: (1000, 4895), Kích thước ảnh AI dịch: (1000, 4895)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/18.jpg
# Kích thước ảnh gốc: (1000, 4595), Kích thước ảnh AI dịch: (1000, 4595)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/25.jpg
# Kích thước ảnh gốc: (1000, 3875), Kích thước ảnh AI dịch: (1000, 3875)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/3.jpg
# Kích thước ảnh gốc: (1000, 5000), Kích thước ảnh AI dịch: (1000, 5000)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/19.jpg
# Kích thước ảnh gốc: (1000, 4295), Kích thước ảnh AI dịch: (1000, 4295)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/9.jpg
#
# Đang xử lý batch 2/3 (10 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '135')]
# ['12.png', '13.png', '5.png', '20.png', '14.png', '24.png', '1.png', '2.png', '8.png', '4.png']
# Nhận được 10 file từ batch 2
# Kích thước ảnh gốc: (1000, 4335), Kích thước ảnh AI dịch: (1000, 4335)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/12.jpg
# Kích thước ảnh gốc: (1000, 2270), Kích thước ảnh AI dịch: (1000, 2270)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/13.jpg
# Kích thước ảnh gốc: (1000, 4775), Kích thước ảnh AI dịch: (1000, 4775)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/5.jpg
# Kích thước ảnh gốc: (1000, 5000), Kích thước ảnh AI dịch: (1000, 5000)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/20.jpg
# Kích thước ảnh gốc: (1000, 3545), Kích thước ảnh AI dịch: (1000, 3545)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/14.jpg
# Kích thước ảnh gốc: (1000, 3575), Kích thước ảnh AI dịch: (1000, 3575)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/24.jpg
# Kích thước ảnh gốc: (1000, 3865), Kích thước ảnh AI dịch: (1000, 3865)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/1.jpg
# Kích thước ảnh gốc: (1000, 3410), Kích thước ảnh AI dịch: (1000, 3410)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/2.jpg
# Kích thước ảnh gốc: (1000, 3920), Kích thước ảnh AI dịch: (1000, 3920)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/8.jpg
# Kích thước ảnh gốc: (1000, 2640), Kích thước ảnh AI dịch: (1000, 2640)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/4.jpg
#
# Đang xử lý batch 3/3 (5 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '135')]
# ['15.png', '16.png', '10.png', '6.png', '21.png']
# Nhận được 5 file từ batch 3
# Kích thước ảnh gốc: (1000, 3220), Kích thước ảnh AI dịch: (1000, 3220)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/15.jpg
# Kích thước ảnh gốc: (1000, 5000), Kích thước ảnh AI dịch: (1000, 5000)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/16.jpg
# Kích thước ảnh gốc: (1000, 4330), Kích thước ảnh AI dịch: (1000, 4330)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/10.jpg
# Kích thước ảnh gốc: (1000, 2275), Kích thước ảnh AI dịch: (1000, 2275)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/6.jpg
# Kích thước ảnh gốc: (1000, 4415), Kích thước ảnh AI dịch: (1000, 4415)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/135/21.jpg
# Yule 136 ['/home/aorus/workspaces/test_commic/data/Yule/Raw/136/17.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/11.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/7.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/18.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/3.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/19.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/9.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/12.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/13.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/5.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/20.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/14.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/1.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/2.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/8.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/4.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/15.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/16.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/10.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/136/6.jpg']
# Tổng số trang: 20, chia thành 2 batch
#
# Đang xử lý batch 1/2 (10 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '136')]
# ['17.png', '11.png', '7.png', '18.png', '3.png', '19.png', '9.png', '12.png', '13.png', '5.png']
# Nhận được 10 file từ batch 1
# Kích thước ảnh gốc: (1000, 5545), Kích thước ảnh AI dịch: (1000, 5545)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/17.jpg
# Kích thước ảnh gốc: (1000, 3350), Kích thước ảnh AI dịch: (1000, 3350)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/11.jpg
# Kích thước ảnh gốc: (1000, 3840), Kích thước ảnh AI dịch: (1000, 3840)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/7.jpg
# Kích thước ảnh gốc: (1000, 3770), Kích thước ảnh AI dịch: (1000, 3770)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/18.jpg
# Kích thước ảnh gốc: (1000, 2005), Kích thước ảnh AI dịch: (1000, 2005)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/3.jpg
# Kích thước ảnh gốc: (1000, 4985), Kích thước ảnh AI dịch: (1000, 4985)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/19.jpg
# Kích thước ảnh gốc: (1000, 3635), Kích thước ảnh AI dịch: (1000, 3635)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/9.jpg
# Kích thước ảnh gốc: (1000, 4365), Kích thước ảnh AI dịch: (1000, 4365)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/12.jpg
# Kích thước ảnh gốc: (1000, 4990), Kích thước ảnh AI dịch: (1000, 4990)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/13.jpg
# Kích thước ảnh gốc: (1000, 3935), Kích thước ảnh AI dịch: (1000, 3935)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/5.jpg
#
# Đang xử lý batch 2/2 (10 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '136')]
# ['20.png', '14.png', '1.png', '2.png', '8.png', '4.png', '15.png', '16.png', '10.png', '6.png']
# Nhận được 10 file từ batch 2
# Kích thước ảnh gốc: (1000, 3373), Kích thước ảnh AI dịch: (1000, 3373)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/20.jpg
# Kích thước ảnh gốc: (1000, 4910), Kích thước ảnh AI dịch: (1000, 4910)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/14.jpg
# Kích thước ảnh gốc: (1000, 3880), Kích thước ảnh AI dịch: (1000, 3880)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/1.jpg
# Kích thước ảnh gốc: (1000, 4630), Kích thước ảnh AI dịch: (1000, 4630)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/2.jpg
# Kích thước ảnh gốc: (1000, 4350), Kích thước ảnh AI dịch: (1000, 4350)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/8.jpg
# Kích thước ảnh gốc: (1000, 4130), Kích thước ảnh AI dịch: (1000, 4130)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/4.jpg
# Kích thước ảnh gốc: (1000, 5040), Kích thước ảnh AI dịch: (1000, 5040)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/15.jpg
# Kích thước ảnh gốc: (1000, 4705), Kích thước ảnh AI dịch: (1000, 4705)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/16.jpg
# Kích thước ảnh gốc: (1000, 4175), Kích thước ảnh AI dịch: (1000, 4175)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/10.jpg
# Kích thước ảnh gốc: (1000, 5215), Kích thước ảnh AI dịch: (1000, 5215)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/136/6.jpg
# Yule 137 ['/home/aorus/workspaces/test_commic/data/Yule/Raw/137/26.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/17.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/11.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/23.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/7.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/22.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/18.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/25.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/3.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/19.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/9.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/12.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/28.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/13.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/5.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/20.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/14.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/24.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/1.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/2.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/8.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/4.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/15.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/16.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/10.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/27.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/6.jpg', '/home/aorus/workspaces/test_commic/data/Yule/Raw/137/21.jpg']
# Tổng số trang: 28, chia thành 3 batch
#
# Đang xử lý batch 1/3 (10 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '137')]
# ['26.png', '17.png', '11.png', '23.png', '7.png', '22.png', '18.png', '25.png', '3.png', '19.png']
# Nhận được 10 file từ batch 1
# Kích thước ảnh gốc: (1000, 4935), Kích thước ảnh AI dịch: (1000, 4935)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/26.jpg
# Kích thước ảnh gốc: (1000, 3185), Kích thước ảnh AI dịch: (1000, 3185)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/17.jpg
# Kích thước ảnh gốc: (1000, 3390), Kích thước ảnh AI dịch: (1000, 3390)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/11.jpg
# Kích thước ảnh gốc: (1000, 3530), Kích thước ảnh AI dịch: (1000, 3530)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/23.jpg
# Kích thước ảnh gốc: (1000, 4900), Kích thước ảnh AI dịch: (1000, 4900)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/7.jpg
# Kích thước ảnh gốc: (1000, 3650), Kích thước ảnh AI dịch: (1000, 3650)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/22.jpg
# Kích thước ảnh gốc: (1000, 4395), Kích thước ảnh AI dịch: (1000, 4395)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/18.jpg
# Kích thước ảnh gốc: (1000, 5000), Kích thước ảnh AI dịch: (1000, 5000)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/25.jpg
# Kích thước ảnh gốc: (1000, 3795), Kích thước ảnh AI dịch: (1000, 3795)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/3.jpg
# Kích thước ảnh gốc: (1000, 4125), Kích thước ảnh AI dịch: (1000, 4125)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/19.jpg
#
# Đang xử lý batch 2/3 (10 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '137')]
# ['9.png', '12.png', '28.png', '13.png', '5.png', '20.png', '14.png', '24.png', '1.png', '2.png']
# Nhận được 10 file từ batch 2
# Kích thước ảnh gốc: (1000, 4810), Kích thước ảnh AI dịch: (1000, 4810)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/9.jpg
# Kích thước ảnh gốc: (1000, 5000), Kích thước ảnh AI dịch: (1000, 5000)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/12.jpg
# Kích thước ảnh gốc: (1000, 4790), Kích thước ảnh AI dịch: (1000, 4790)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/28.jpg
# Kích thước ảnh gốc: (1000, 4005), Kích thước ảnh AI dịch: (1000, 4005)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/13.jpg
# Kích thước ảnh gốc: (1000, 4340), Kích thước ảnh AI dịch: (1000, 4340)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/5.jpg
# Kích thước ảnh gốc: (1000, 4740), Kích thước ảnh AI dịch: (1000, 4740)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/20.jpg
# Kích thước ảnh gốc: (1000, 3395), Kích thước ảnh AI dịch: (1000, 3395)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/14.jpg
# Kích thước ảnh gốc: (1000, 2765), Kích thước ảnh AI dịch: (1000, 2765)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/24.jpg
# Kích thước ảnh gốc: (1000, 4410), Kích thước ảnh AI dịch: (1000, 4410)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/1.jpg
# Kích thước ảnh gốc: (1000, 4410), Kích thước ảnh AI dịch: (1000, 4410)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/2.jpg
#
# Đang xử lý batch 3/3 (8 trang)
# [('target_lang', 'vietnamese'), ('story_name', 'Yule'), ('chapter_number', '137')]
# ['8.png', '4.png', '15.png', '16.png', '10.png', '27.png', '6.png', '21.png']
# Nhận được 8 file từ batch 3
# Kích thước ảnh gốc: (1000, 4670), Kích thước ảnh AI dịch: (1000, 4670)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/8.jpg
# Kích thước ảnh gốc: (1000, 4895), Kích thước ảnh AI dịch: (1000, 4895)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/4.jpg
# Kích thước ảnh gốc: (1000, 4315), Kích thước ảnh AI dịch: (1000, 4315)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/15.jpg
# Kích thước ảnh gốc: (1000, 4835), Kích thước ảnh AI dịch: (1000, 4835)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/16.jpg
# Kích thước ảnh gốc: (1000, 4350), Kích thước ảnh AI dịch: (1000, 4350)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/10.jpg
# Kích thước ảnh gốc: (1000, 5000), Kích thước ảnh AI dịch: (1000, 5000)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/27.jpg
# Kích thước ảnh gốc: (1000, 3645), Kích thước ảnh AI dịch: (1000, 3645)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/6.jpg
# Kích thước ảnh gốc: (1000, 4800), Kích thước ảnh AI dịch: (1000, 4800)
# Đường dẫn ảnh dịch tay: test_commic/data/Yule/team_translated/137/21.jpg
